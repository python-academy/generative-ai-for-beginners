# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 41, 20089, 374, 279, 18172, 11841, 505, 279, 8219, 323, 279, 7928, 304, 279, 25450, 744, 13, 1102, 374, 264, 6962, 14880, 449, 264, 3148, 832, 7716, 52949, 339, 430, 315, 279, 8219, 11, 719, 1403, 9976, 7561, 34902, 3115, 430, 315, 682, 279, 1023, 33975, 304, 279, 25450, 744, 11093, 13, 50789, 374, 832, 315, 279, 72021, 6302, 9621, 311, 279, 19557, 8071, 304, 279, 3814, 13180, 11, 323, 706, 1027, 3967, 311, 14154, 86569, 2533, 1603, 12715, 3925, 13, 1102, 374, 7086, 1306, 279, 13041, 10087, 50789, 8032, 777, 60, 3277, 19894, 505, 9420, 11, 50789, 649, 387, 10107, 3403, 369, 1202, 27000, 3177, 311, 6445, 9621, 35612, 17706, 508, 60, 323, 374, 389, 5578, 279, 4948, 1481, 1315, 478, 5933, 1665, 304, 279, 3814, 13180, 1306, 279, 17781, 323, 50076, 627]
# [b'\n',
#  b'J',
#  b'upiter',
#  b' is',
#  b' the',
#  b' fifth',
#  b' planet',
#  b' from',
#  b' the',
#  b' Sun',
#  b' and',
#  b' the',
#  b' largest',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b'.',
#  b' It',
#  b' is',
#  b' a',
#  b' gas',
#  b' giant',
#  b' with',
#  b' a',
#  b' mass',
#  b' one',
#  b'-th',
#  b'ousand',
#  b'th',
#  b' that',
#  b' of',
#  b' the',
#  b' Sun',
#  b',',
#  b' but',
#  b' two',
#  b'-and',
#  b'-a',
#  b'-half',
#  b' times',
#  b' that',
#  b' of',
#  b' all',
#  b' the',
#  b' other',
#  b' planets',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b' combined',
#  b'.',
#  b' Jupiter',
#  b' is',
#  b' one',
#  b' of',
#  b' the',
#  b' brightest',
#  b' objects',
#  b' visible',
#  b' to',
#  b' the',
#  b' naked',
#  b' eye',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b',',
#  b' and',
#  b' has',
#  b' been',
#  b' known',
#  b' to',
#  b' ancient',
#  b' civilizations',
#  b' since',
#  b' before',
#  b' recorded',
#  b' history',
#  b'.',
#  b' It',
#  b' is',
#  b' named',
#  b' after',
#  b' the',
#  b' Roman',
#  b' god',
#  b' Jupiter',
#  b'.[',
#  b'19',
#  b']',
#  b' When',
#  b' viewed',
#  b' from',
#  b' Earth',
#  b',',
#  b' Jupiter',
#  b' can',
#  b' be',
#  b' bright',
#  b' enough',
#  b' for',
#  b' its',
#  b' reflected',
#  b' light',
#  b' to',
#  b' cast',
#  b' visible',
#  b' shadows',
#  b',[',
#  b'20',
#  b']',
#  b' and',
#  b' is',
#  b' on',
#  b' average',
#  b' the',
#  b' third',
#  b'-b',
#  b'right',
#  b'est',
#  b' natural',
#  b' object',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b' after',
#  b' the',
#  b' Moon',
#  b' and',
#  b' Venus',
#  b'.\n']

# %% [markdown]
# ### Exercise 2: Validate Grok API Key Setup
#
# Run the code below to verify that your Grok endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
import os
from groq import Groq

from dotenv import load_dotenv
load_dotenv()

client = Groq(
    api_key=os.getenv("GROK_API_KEY"),
)

deployment="llama-3.3-70b-versatile"

## Updated
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]       
    response = client.chat.completions.create(   
        model=deployment,                                         
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=1024
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# "by the dawn's early light" (The Star-Spangled Banner, US national anthem)

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# **Lesson Title:** Exploring the Martian War of 2076: A Futuristic Historical Perspective
#
# **Grade Level:** 9-12
#
# **Objectives:**
#
# 1. Students will understand the historical context and events leading up to the Martian War of 2076.
# 2. Students will analyze the causes and consequences of the war from multiple perspectives.
# 3. Students will develop critical thinking skills by evaluating the implications of a hypothetical interplanetary conflict.
# 4. Students will demonstrate creativity and problem-solving skills through a futuristic scenario-based activity.
#
# **Materials:**
#
# * Whiteboard and markers
# * Map of the solar system
# * Timeline of major events leading up to the Martian War of 2076 (hypothetical)
# * Handouts with guiding questions
# * Access to online resources and multimedia materials (e.g., videos, podcasts, articles)
# * Scenario-based activity worksheets
#
# **Lesson Plan:**
#
# **Introduction (10 minutes)**
#
# 1. Introduce the concept of the Martian War of 2076, a hypothetical conflict between Earth and a human settlement on Mars.
# 2. Ask students to imagine a future where humanity has colonized Mars and the tensions that might arise between the two planets.
# 3. Write down key questions on the board, such as:
# 	* What led to the war?
# 	* What were the main causes and consequences of the conflict?
# 	* How did the war affect the relationship between Earth and Mars?
#
# **Historical Context (20 minutes)**
#
# 1. Provide a brief overview of the events leading up to the Martian War of 2076, including:
# 	* The establishment of the first human settlement on Mars in the mid-21st century
# 	* The growth of the Martian economy and its increasing independence from Earth
# 	* The rise of tensions between Earth and Mars over resources, trade, and governance
# 2. Use a timeline to illustrate the key events and milestones in the lead-up to the war.
# 3. Discuss the role of key figures, such as politicians, scientists, and entrepreneurs, in shaping the course of events.
#
# **Causes and Consequences (20 minutes)**
#
# 1. Divide the class into small groups and assign each group a different perspective on the war:
# 	* Earth's government
# 	* The Martian settlement
# 	* A neutral third party (e.g., a lunar colony or an asteroid mining corporation)
# 2. Ask each group to analyze the causes and consequences of the war from their assigned perspective.
# 3. Provide guiding questions, such as:
# 	* What were the main motivations and goals of each side?
# 	* How did the war affect the economy, environment, and society on both Earth and Mars?
# 	* What were the long-term consequences of the conflict?
#
# **Scenario-Based Activity (30 minutes)**
#
# 1. Distribute scenario-based activity worksheets, which present a hypothetical situation:
# 	* A new crisis is emerging between Earth and Mars, threatening to reignite the conflict.
# 	* Students must work in groups to develop a plan to prevent the outbreak of war.
# 2. Ask students to consider the following factors:
# 	* Diplomatic efforts to resolve the crisis
# 	* Economic incentives and trade agreements
# 	* Military preparedness and defense strategies
# 	* Environmental and social implications of the conflict
# 3. Encourage students to think creatively and develop innovative solutions to the crisis.
#
# **Conclusion (10 minutes)**
#
# 1. Ask each group to present their plan to prevent the outbreak of war.
# 2. Facilitate a class discussion to compare and contrast the different approaches.
# 3. Reflect on the lessons learned from the Martian War of 2076 and how they can be applied to real-world conflicts and challenges.
#
# **Assessment:**
#
# * Participation in class discussions and activities (20%)
# * Group presentation and plan to prevent the outbreak of war (30%)
# * Written reflection on the lessons learned from the Martian War of 2076 (30%)
# * Scenario-based activity worksheet (20%)
#
# **Extension:**
#
# * Ask students to research and create a multimedia presentation (e.g., video, podcast, infographic) about the Martian War of 2076.
# * Invite a guest speaker to discuss the implications of space exploration and colonization on international relations.
# * Conduct a debate on the ethics of interplanetary conflict and the responsibilities of nations in the face of emerging crises.

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example


## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Hey there, little buddy! Let's talk about a really cool planet called Jupiter. It's the biggest planet in our whole solar system! Jupiter is like a big ball of gas, and it's really, really far away from us. But it's so big and bright that we can see it in the sky at night, even without a special telescope. It's like a big shiny star! People have been looking at Jupiter for thousands and thousands of years, and it's even named after a special god from a long time ago. Isn't that cool?

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.chat.completions.create(
    model=deployment,
    messages=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Wow, you really don't know much about this, do you? The 2020 World Series was played at Globe Life Field in Arlington, Texas. It was a neutral site due to the whole COVID-19 pandemic thing. Happy now?

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
