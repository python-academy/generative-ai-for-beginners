# %% [markdown]
# # Chapter 7: Building Chat Applications
# ## Groq API Quickstart

# %% [markdown]
# # Overview
# "Large language models are functions that map text to text. Given an input string of text, a large language model tries to predict the text that will come next"(1). This "quickstart" notebook will introduce users to high-level LLM concepts, core package requirements for getting started with AML, a soft introduction to prompt design, and several short examples of different use cases.

# %% [markdown]
# ## Table of Contents
#
# [Overview](#overview)
# [How to use Groq Service](#how-to-use-openai-service)
# [1. Creating your Groq Service](#1.-creating-your-openai-service)
# [2. Installation](#2.-installation)
# [3. Credentials](#3.-credentials)
#
# [Use Cases](#use-cases)
# [1. Summarize Text](#1.-summarize-text)
# [2. Classify Text](#2.-classify-text)
# [3. Generate New Product Names](#3.-generate-new-product-names)
# [4. Fine Tune a Classifier](#4.fine-tune-a-classifier)
#
# [References](#references)

# %% [markdown]
# ### Build your first prompt
# This short exercise will provide a basic introduction for submitting prompts to an Groq model for a simple task "summarization".
#
#
# **Steps**:
# 1. Install Groq library in your python environment
# 2. Load standard helper libraries and set your typical Groq security credentials for the Groq Service that you've created
# 3. Choose a model for your task
# 4. Create a simple prompt for the model
# 5. Submit your request to the model API!

# %% [markdown]
# ### 1. Install Groq

# %%
# %pip install groq python-dotenv

# %% [markdown]
# ### 2. Import helper libraries and instantiate credentials

# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("GROK_API_KEY","").strip()
assert API_KEY, "ERROR: OpenGrok AI Key is missing"
client = Groq(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. Finding the right model
# The GPT-3.5-turbo or GPT-4 models can understand and generate natural language.

# %%
# Select the General Purpose versatile model for text
model = "llama-3.3-70b-versatile"

# %% [markdown]
# ## 4. Prompt Design
#
# "The magic of large language models is that by being trained to minimize this prediction error over vast quantities of text, the models end up learning concepts useful for these predictions. For example, they learn concepts like"(1):
#
# * how to spell
# * how grammar works
# * how to paraphrase
# * how to answer questions
# * how to hold a conversation
# * how to write in many languages
# * how to code
# * etc.
#
# #### How to control a large language model
# "Of all the inputs to a large language model, by far the most influential is the text prompt(1).
#
# Large language models can be prompted to produce output in a few ways:
#
# Instruction: Tell the model what you want
# Completion: Induce the model to complete the beginning of what you want
# Demonstration: Show the model what you want, with either:
# A few examples in the prompt
# Many hundreds or thousands of examples in a fine-tuning training dataset"
#
#
#
# #### There are three basic guidelines to creating prompts:
#
# **Show and tell**. Make it clear what you want either through instructions, examples, or a combination of the two. If you want the model to rank a list of items in alphabetical order or to classify a paragraph by sentiment, show it that's what you want.
#
# **Provide quality data**. If you're trying to build a classifier or get the model to follow a pattern, make sure that there are enough examples. Be sure to proofread your examples — the model is usually smart enough to see through basic spelling mistakes and give you a response, but it also might assume this is intentional and it can affect the response.
#
# **Check your settings.** The temperature and top_p settings control how deterministic the model is in generating a response. If you're asking it for a response where there's only one right answer, then you'd want to set these lower. If you're looking for more diverse responses, then you might want to set them higher. The number one mistake people make with these settings is assuming that they're "cleverness" or "creativity" controls.

# %% [markdown]
# ### 5. Submit!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.chat.completions.create(
  model=model,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

print(response.choices[0].message.content)
# Out:
# The use of Oxford commas, also known as serial commas, is a topic of debate among writers, editors, and linguists. While some argue that Oxford commas should always be used for clarity, others believe that they can be omitted in certain cases without affecting the meaning of a sentence.
#
# Here are some arguments for and against always using Oxford commas:
#
# **Arguments for always using Oxford commas:**
#
# 1. **Clarity**: Oxford commas can help to avoid ambiguity in sentences with multiple items in a list. For example: "I invited my parents, J.K. Rowling and the Queen" (without Oxford comma) versus "I invited my parents, J.K. Rowling, and the Queen" (with Oxford comma).
# 2. **Consistency**: Using Oxford commas consistently can make your writing more readable and easier to follow.
# 3. **Style guides**: Some style guides, such as the Chicago Manual of Style, recommend using Oxford commas.
#
# **Arguments against always using Oxford commas:**
#
# 1. **Conciseness**: Omitting Oxford commas can make sentences more concise and easier to read, especially in cases where the meaning is clear without them.
# 2. **Journalistic style**: Many news organizations and journalistic publications, such as The New York Times, omit Oxford commas to save space and improve readability.
# 3. **Variety**: Allowing for flexibility in the use of Oxford commas can help to create a more varied and interesting writing style.
#
# **When to use Oxford commas:**
#
# 1. **To avoid ambiguity**: Use Oxford commas when the meaning of a sentence could be unclear without them.
# 2. **In formal writing**: Oxford commas are often preferred in formal writing, such as academic or technical writing, to ensure clarity and precision.
# 3. **In lists with complex items**: Use Oxford commas when listing items that themselves contain commas or other punctuation marks.
#
# **When to omit Oxford commas:**
#
# 1. **In informal writing**: Omitting Oxford commas can be acceptable in informal writing, such as blog posts or social media updates, where brevity and concision are more important.
# 2. **In simple lists**: If the items in a list are simple and clearly separated, Oxford commas may not be necessary.
# 3. **In journalistic or news writing**: Omitting Oxford commas is common in journalistic writing, where space is limited and readability is crucial.
#
# Ultimately, whether to use Oxford commas always, never, or sometimes depends on your writing style, the context, and the audience you're writing for. It's essential to be consistent in your use of Oxford commas within a single piece of writing and to follow the guidelines of your chosen style guide, if applicable.

# %% [markdown]
# ### Repeat the same call, how do the results compare?

# %%
response = client.chat.completions.create(
  model=model,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

print(response.choices[0].message.content)
# Out:
# The Oxford comma, also known as the serial comma, is a comma used after the penultimate item in a list of three or more items before "and" or "or." The debate about whether to use the Oxford comma has been ongoing, with some arguing it should always be used, while others believe it's optional or unnecessary.
#
# Arguments in favor of always using the Oxford comma:
#
# 1. **Clarity**: The Oxford comma can help prevent ambiguity in sentences, especially when listing items. For example: "I invited my parents, J.K. Rowling and the Queen" (without Oxford comma) implies that J.K. Rowling and the Queen are my parents, whereas "I invited my parents, J.K. Rowling, and the Queen" (with Oxford comma) makes it clear they are separate individuals.
# 2. **Consistency**: Using the Oxford comma consistently can make your writing more readable and easier to follow.
# 3. **Style guides**: Some style guides, such as the Chicago Manual of Style, recommend using the Oxford comma.
#
# Arguments against always using the Oxford comma:
#
# 1. **Brevity**: Omitting the Oxford comma can make sentences more concise and easier to read, especially in journalistic or informal writing.
# 2. **Regional variations**: In some regions, such as the UK, the Oxford comma is less commonly used, and its omission is not considered an error.
# 3. **Style guides**: Other style guides, such as the AP Stylebook, recommend against using the Oxford comma.
#
# Ultimately, whether to use the Oxford comma depends on:
#
# 1. **Personal preference**: If you're writing for yourself or a specific audience, you can choose to use or omit the Oxford comma based on your personal style.
# 2. **Style guide requirements**: If you're writing for a publication or following a specific style guide, you should adhere to their guidelines regarding the Oxford comma.
# 3. **Context**: Consider the context and potential ambiguity of the sentence. If the Oxford comma clarifies the meaning, it's a good idea to use it.
#
# In summary, while there are valid arguments for and against always using the Oxford comma, the decision ultimately depends on your personal style, the requirements of your style guide, and the context of the sentence.

# %% [markdown]
# ## Summarize Text
# #### Challenge
# Summarize text by adding a 'tl;dr:' to the end of a text passage. Notice how the model understands how to perform a number of tasks with no additional instructions. You can experiment with more descriptive prompts than tl;dr to modify the model’s behavior and customize the summarization you receive(3).
#
# Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.
#
#
#
# Tl;dr

# %% [markdown]
# # Exercises for several use cases
# 1. Summarize Text
# 2. Classify Text
# 3. Generate New Product Names

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by \
pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, \
this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, \
humans can generally perform a new language task from only a few examples or from simple instructions - something \
that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly \
improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with \
prior state-of-the-art fine-tuning approaches.\n\nTl;dr"
# Out:
# Prompt:
#  Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.
#
# Tl;dr

# %%
#Setting a few additional, typical parameters during API Call

response = client.chat.completions.create(
  model=model,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

print(response.choices[0].message.content)
# Out:
# Large language models can perform new tasks with few examples, similar to humans, and sometimes even match the performance of models that have been fine-tuned on large datasets.

# %% [markdown]
# ## Classify Text
# #### Challenge
# Classify items into categories provided at inference time. In the following example, we provide both the categories and the text to classify in the prompt(*playground_reference).
#
# Customer Inquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:
#
# Classified category:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)
# Out:
# Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]
#
# inquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:
#
# Classified category:

# %%
#Setting a few additional, typical parameters during API Call

response = client.chat.completions.create(
  model=model,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

print(response.choices[0].message.content)
# Out:
# The classified category for this inquiry is: Hardware Support.

# %% [markdown]
# ## Generate New Product Names
# #### Challenge
# Create product names from examples words. Here we include in the prompt information about the product we are going to generate names for. We also provide a similar example to show the pattern we wish to receive. We have also set the temperature value high to increase randomness and more innovative responses.
#
# Product description: A home milkshake maker
# Seed words: fast, healthy, compact.
# Product names: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Product description: A pair of shoes that can fit any foot size.
# Seed words: adaptable, fit, omni-fit.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)
# Out:
# Product description: A home milkshake maker
# Seed words: fast, healthy, compact.
# Product names: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Product description: A pair of shoes that can fit any foot size.
# Seed words: adaptable, fit, omni-fit.

# %%
#Setting a few additional, typical parameters during API Call

response = client.chat.completions.create(
  model=model,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}])

print(response.choices[0].message.content)
# Out:
# Here are some potential product descriptions and names based on the provided information:
#
# **Home Milkshake Maker:**
#
# Product Description: Introducing the QuickShake, a fast and healthy way to create your favorite milkshakes at home. This compact machine is perfect for families, fitness enthusiasts, and anyone looking for a quick and delicious treat. With its easy-to-use interface and cleaning system, you can enjoy a variety of milkshakes in no time.
#
# Alternative Product Names:
# - HomeShaker: implies a fun, home-based experience
# - Fit Shaker: suggests a healthy and fitness-oriented product
# - Shake Maker: straightforward and to the point
#
# **Adaptable Shoes:**
#
# Product Description: Say goodbye to shoe size hassles with OmniFit, the revolutionary new footwear that adapts to any foot size. These omni-fit shoes provide a comfortable and secure fit, regardless of your foot shape or size. Whether you're looking for a versatile shoe for daily wear or an adaptable option for special occasions, OmniFit has got you covered.
#
# Alternative Product Names:
# - FitForAll: emphasizes the adaptable nature of the shoes
# - Adaptix: suggests a cutting-edge, innovative product
# - SizeLess: implies a shoe that transcends traditional sizing limitations
